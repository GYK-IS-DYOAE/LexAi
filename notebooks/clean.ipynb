# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\zeyne\Desktop\LexAi\data\interim\kararlar_segment.csv").head(5000)

# %%
df
# Out:
#         Sira               Daire     Esas No    Karar No       Tarih  \
# 0        1.0    8. Hukuk Dairesi    2023/938   2023/4427  18.09.2023
# 1        2.0  Hukuk Genel Kurulu    2022/830   2022/1591  24.11.2022
# 2        3.0    2. Hukuk Dairesi  2022/10625   2023/1076  15.03.2023
# 3        4.0    3. Hukuk Dairesi   2022/8509     2023/75  18.01.2023
# 4        5.0    2. Hukuk Dairesi  2022/11174    2023/845  06.03.2023
# ...      ...                 ...         ...         ...         ...
# 4995  5104.0   14. Hukuk Dairesi   2016/9733      2018/6  08.01.2018
# 4996  5105.0   13. Hukuk Dairesi  2016/10738  2016/11863  28.04.2016
# 4997  5106.0    8. Hukuk Dairesi   2019/1290   2019/8466  02.10.2019
# 4998  5107.0   11. Hukuk Dairesi   2024/6313   2024/8505  02.12.2024
# 4999  5108.0    5. Hukuk Dairesi  2022/15698   2023/2127  07.03.2023
#
#                                             Karar Metni  \
# 0     MAHKEMESİ: Kadastro Mahkemesi\nSAYISI: 2008/23...
# ...

# %%
df.to_csv(r"C:\Users\zeyne\Desktop\LexAi\data\interim\segment_5000.csv")
